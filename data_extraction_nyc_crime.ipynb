# %% [markdown]
# # NYC Crimes, 2013 - 2023

# %% [markdown]
# ## Data collection from NYC OpenData API
# This section will only be run once.\
# API source: https://data.cityofnewyork.us/Public-Safety/NYPD-Complaint-Data-Historic/qgea-i56i/about_data

# %%
# Import dependencies
import json
import pandas as pd
import requests
import time
import urllib.parse

# %%
# Define parameters for query
begin_date = '2013-01-01' # Enter the YYYY-MM-DD
end_date = '2023-12-31'
borough = 'MANHATTAN' #Choose one of the five boroughs

# %%
# String for query
query_string = f"boro_nm = '{borough}' AND rpt_dt >= '{begin_date}' AND rpt_dt <= '{end_date}'"

# Use urllib.parse.quote_plus to format the string for URL
safe_string = urllib.parse.quote_plus(query_string)

# %%
# Define variables for the While Loop. Create empty list to house the dictionaries created during the loop
records_count = 1
records = 0
offset = 0
set = 1
limit = 1000 # Per API documentation, can only pull 1000 records at a time
data_list = []

# %%
# While loop. While len of json_results > 0, query the URL.
while records_count != 0:
    # Define the URL for the JSON.
    url = f"https://data.cityofnewyork.us/resource/qgea-i56i.json?$where={safe_string}&$limit={limit}&$offset={offset}&$order=cmplnt_num"
    # Get the JSON
    json_results = requests.get(url).json()
    # Add to the number of results to track total number
    records += len(json_results)
    # Print message to console showing number of rows extracted, show set number.
    print(f"Extracting {len(json_results)} rows of data, Set # {set}")
    
    # Extract and store requested data into lists
    for x in range(len(json_results)):

        # Parse data into variables
        complaint_no = json_results[x]['cmplnt_num']
        reported_date = json_results[x]['rpt_dt']
        borough_name = json_results[x]['boro_nm']
        ofns = json_results[x]['ofns_desc']
        pd_desc = json_results[x]['pd_desc']
        law_cat_cd = json_results[x]['law_cat_cd']
        # Some records contain blank values in the lat/lon fields; as a result, the JSON for this [x] does not have 'latitude' or 'longitude' keys. Use try/except to store None into the variables for these records
        try:
            lat = json_results[x]['latitude']
        except:
            lat = None
        try:
            lon = json_results[x]['longitude']
        except: 
            lon = None

        # Append above data as a dictionary into data list
        data_list.append({
            "Complaint_No":complaint_no,
            "Reported_Dt":reported_date,
            "Borough_Name":borough_name,
            "Ofns_Desc": ofns,
            "PD_Desc":pd_desc,
            "Law_Cat": law_cat_cd,
            "Latitude": lat,
            "Longitude": lon
        })

    # Update the offset number by 1000
    offset = limit + offset
    # Update the set count
    set += 1
    # Update the records_count variable with count of json_results. Once it hits zero, loop will terminate
    records_count = len(json_results)
    # Delay of 1 second to avoid rate limiting
    time.sleep(1)
# Once loop condition is no longer true, print total number of records    
else: print(f"Total number of records extracted: {records}")
# Out:
# Extracting 1000 rows of data, Set # 1
# Extracting 1000 rows of data, Set # 2
# Extracting 1000 rows of data, Set # 3
# Extracting 1000 rows of data, Set # 4
# Extracting 1000 rows of data, Set # 5
# Extracting 1000 rows of data, Set # 6
# Extracting 1000 rows of data, Set # 7
# Extracting 1000 rows of data, Set # 8
# Extracting 1000 rows of data, Set # 9
# Extracting 1000 rows of data, Set # 10
# Extracting 1000 rows of data, Set # 11
# Extracting 1000 rows of data, Set # 12
# Extracting 1000 rows of data, Set # 13
# Extracting 1000 rows of data, Set # 14
# Extracting 1000 rows of data, Set # 15
# Extracting 1000 rows of data, Set # 16
# Extracting 1000 rows of data, Set # 17
# Extracting 1000 rows of data, Set # 18
# Extracting 1000 rows of data, Set # 19
# Extracting 1000 rows of data, Set # 20
# Extracting 1000 rows of data, Set # 21
# Extracting 1000 rows of data, Set # 22
# Extracting 1000 rows of data, Set # 23
# Extracting 1000 rows of data, Set # 24
# Extracting 1000 rows of data, Set # 25
# Extracting 1000 rows of data, Set # 26
# Extracting 1000 rows of data, Set # 27
# Extracting 1000 rows of data, Set # 28
# Extracting 1000 rows of data, Set # 29
# Extracting 1000 rows of data, Set # 30
# Extracting 1000 rows of data, Set # 31
# Extracting 1000 rows of data, Set # 32
# Extracting 1000 rows of data, Set # 33
# Extracting 1000 rows of data, Set # 34
# Extracting 1000 rows of data, Set # 35
# Extracting 1000 rows of data, Set # 36
# Extracting 1000 rows of data, Set # 37
# Extracting 1000 rows of data, Set # 38
# Extracting 1000 rows of data, Set # 39
# Extracting 1000 rows of data, Set # 40
# Extracting 1000 rows of data, Set # 41
# Extracting 1000 rows of data, Set # 42
# Extracting 1000 rows of data, Set # 43
# Extracting 1000 rows of data, Set # 44
# Extracting 1000 rows of data, Set # 45
# Extracting 1000 rows of data, Set # 46
# Extracting 1000 rows of data, Set # 47
# Extracting 1000 rows of data, Set # 48
# Extracting 1000 rows of data, Set # 49
# Extracting 1000 rows of data, Set # 50
# Extracting 1000 rows of data, Set # 51
# Extracting 1000 rows of data, Set # 52
# Extracting 1000 rows of data, Set # 53
# Extracting 1000 rows of data, Set # 54
# Extracting 1000 rows of data, Set # 55
# Extracting 1000 rows of data, Set # 56
# Extracting 1000 rows of data, Set # 57
# Extracting 1000 rows of data, Set # 58
# Extracting 1000 rows of data, Set # 59
# Extracting 1000 rows of data, Set # 60
# Extracting 1000 rows of data, Set # 61
# Extracting 1000 rows of data, Set # 62
# Extracting 1000 rows of data, Set # 63
# Extracting 1000 rows of data, Set # 64
# Extracting 1000 rows of data, Set # 65
# Extracting 1000 rows of data, Set # 66
# Extracting 1000 rows of data, Set # 67
# Extracting 1000 rows of data, Set # 68
# Extracting 1000 rows of data, Set # 69
# Extracting 1000 rows of data, Set # 70
# Extracting 1000 rows of data, Set # 71
# Extracting 1000 rows of data, Set # 72
# Extracting 1000 rows of data, Set # 73
# Extracting 1000 rows of data, Set # 74
# Extracting 1000 rows of data, Set # 75
# Extracting 1000 rows of data, Set # 76
# Extracting 1000 rows of data, Set # 77
# Extracting 1000 rows of data, Set # 78
# Extracting 1000 rows of data, Set # 79
# Extracting 1000 rows of data, Set # 80
# Extracting 1000 rows of data, Set # 81
# Extracting 1000 rows of data, Set # 82
# Extracting 1000 rows of data, Set # 83
# Extracting 1000 rows of data, Set # 84
# Extracting 1000 rows of data, Set # 85
# Extracting 1000 rows of data, Set # 86
# Extracting 1000 rows of data, Set # 87
# Extracting 1000 rows of data, Set # 88
# Extracting 1000 rows of data, Set # 89
# Extracting 1000 rows of data, Set # 90
# Extracting 1000 rows of data, Set # 91
# Extracting 1000 rows of data, Set # 92
# Extracting 1000 rows of data, Set # 93
# Extracting 1000 rows of data, Set # 94
# Extracting 1000 rows of data, Set # 95
# Extracting 1000 rows of data, Set # 96
# Extracting 1000 rows of data, Set # 97
# Extracting 1000 rows of data, Set # 98
# Extracting 1000 rows of data, Set # 99
# Extracting 1000 rows of data, Set # 100
# Extracting 1000 rows of data, Set # 101
# Extracting 1000 rows of data, Set # 102
# Extracting 1000 rows of data, Set # 103
# Extracting 1000 rows of data, Set # 104
# Extracting 1000 rows of data, Set # 105
# Extracting 1000 rows of data, Set # 106
# Extracting 1000 rows of data, Set # 107
# Extracting 1000 rows of data, Set # 108
# Extracting 1000 rows of data, Set # 109
# Extracting 1000 rows of data, Set # 110
# Extracting 1000 rows of data, Set # 111
# Extracting 1000 rows of data, Set # 112
# Extracting 1000 rows of data, Set # 113
# Extracting 1000 rows of data, Set # 114
# Extracting 1000 rows of data, Set # 115
# Extracting 1000 rows of data, Set # 116
# Extracting 1000 rows of data, Set # 117
# Extracting 1000 rows of data, Set # 118
# Extracting 1000 rows of data, Set # 119
# Extracting 1000 rows of data, Set # 120
# Extracting 1000 rows of data, Set # 121
# Extracting 1000 rows of data, Set # 122
# Extracting 1000 rows of data, Set # 123
# Extracting 1000 rows of data, Set # 124
# Extracting 1000 rows of data, Set # 125
# Extracting 1000 rows of data, Set # 126
# Extracting 1000 rows of data, Set # 127
# Extracting 1000 rows of data, Set # 128
# Extracting 1000 rows of data, Set # 129
# Extracting 1000 rows of data, Set # 130
# Extracting 1000 rows of data, Set # 131
# Extracting 1000 rows of data, Set # 132
# Extracting 1000 rows of data, Set # 133
# Extracting 1000 rows of data, Set # 134
# Extracting 1000 rows of data, Set # 135
# Extracting 1000 rows of data, Set # 136
# Extracting 1000 rows of data, Set # 137
# Extracting 1000 rows of data, Set # 138
# Extracting 1000 rows of data, Set # 139
# Extracting 1000 rows of data, Set # 140
# Extracting 1000 rows of data, Set # 141
# Extracting 1000 rows of data, Set # 142
# Extracting 1000 rows of data, Set # 143
# Extracting 1000 rows of data, Set # 144
# Extracting 1000 rows of data, Set # 145
# Extracting 1000 rows of data, Set # 146
# Extracting 1000 rows of data, Set # 147
# Extracting 1000 rows of data, Set # 148
# Extracting 1000 rows of data, Set # 149
# Extracting 1000 rows of data, Set # 150
# Extracting 1000 rows of data, Set # 151
# Extracting 1000 rows of data, Set # 152
# Extracting 1000 rows of data, Set # 153
# Extracting 1000 rows of data, Set # 154
# Extracting 1000 rows of data, Set # 155
# Extracting 1000 rows of data, Set # 156
# Extracting 1000 rows of data, Set # 157
# Extracting 1000 rows of data, Set # 158
# Extracting 1000 rows of data, Set # 159
# Extracting 1000 rows of data, Set # 160
# Extracting 1000 rows of data, Set # 161
# Extracting 1000 rows of data, Set # 162
# Extracting 1000 rows of data, Set # 163
# Extracting 1000 rows of data, Set # 164
# Extracting 1000 rows of data, Set # 165
# Extracting 1000 rows of data, Set # 166
# Extracting 1000 rows of data, Set # 167
# Extracting 1000 rows of data, Set # 168
# Extracting 1000 rows of data, Set # 169
# Extracting 1000 rows of data, Set # 170
# Extracting 1000 rows of data, Set # 171
# Extracting 1000 rows of data, Set # 172
# Extracting 1000 rows of data, Set # 173
# Extracting 1000 rows of data, Set # 174
# Extracting 1000 rows of data, Set # 175
# Extracting 1000 rows of data, Set # 176
# Extracting 1000 rows of data, Set # 177
# Extracting 1000 rows of data, Set # 178
# Extracting 1000 rows of data, Set # 179
# Extracting 1000 rows of data, Set # 180
# Extracting 1000 rows of data, Set # 181
# Extracting 1000 rows of data, Set # 182
# Extracting 1000 rows of data, Set # 183
# Extracting 1000 rows of data, Set # 184
# Extracting 1000 rows of data, Set # 185
# Extracting 1000 rows of data, Set # 186
# Extracting 1000 rows of data, Set # 187
# Extracting 1000 rows of data, Set # 188
# Extracting 1000 rows of data, Set # 189
# Extracting 1000 rows of data, Set # 190
# Extracting 1000 rows of data, Set # 191
# Extracting 1000 rows of data, Set # 192
# Extracting 1000 rows of data, Set # 193
# Extracting 1000 rows of data, Set # 194
# Extracting 1000 rows of data, Set # 195
# Extracting 1000 rows of data, Set # 196
# Extracting 1000 rows of data, Set # 197
# Extracting 1000 rows of data, Set # 198
# Extracting 1000 rows of data, Set # 199
# Extracting 1000 rows of data, Set # 200
# Extracting 1000 rows of data, Set # 201
# Extracting 1000 rows of data, Set # 202
# Extracting 1000 rows of data, Set # 203
# Extracting 1000 rows of data, Set # 204
# Extracting 1000 rows of data, Set # 205
# Extracting 1000 rows of data, Set # 206
# Extracting 1000 rows of data, Set # 207
# Extracting 1000 rows of data, Set # 208
# Extracting 1000 rows of data, Set # 209
# Extracting 1000 rows of data, Set # 210
# Extracting 1000 rows of data, Set # 211
# Extracting 1000 rows of data, Set # 212
# Extracting 1000 rows of data, Set # 213
# Extracting 1000 rows of data, Set # 214
# Extracting 1000 rows of data, Set # 215
# Extracting 1000 rows of data, Set # 216
# Extracting 1000 rows of data, Set # 217
# Extracting 1000 rows of data, Set # 218
# Extracting 1000 rows of data, Set # 219
# Extracting 1000 rows of data, Set # 220
# Extracting 1000 rows of data, Set # 221
# Extracting 1000 rows of data, Set # 222
# Extracting 1000 rows of data, Set # 223
# Extracting 1000 rows of data, Set # 224
# Extracting 1000 rows of data, Set # 225
# Extracting 1000 rows of data, Set # 226
# Extracting 1000 rows of data, Set # 227
# Extracting 1000 rows of data, Set # 228
# Extracting 1000 rows of data, Set # 229
# Extracting 1000 rows of data, Set # 230
# Extracting 1000 rows of data, Set # 231
# Extracting 1000 rows of data, Set # 232
# Extracting 1000 rows of data, Set # 233
# Extracting 1000 rows of data, Set # 234
# Extracting 1000 rows of data, Set # 235
# Extracting 1000 rows of data, Set # 236
# Extracting 1000 rows of data, Set # 237
# Extracting 1000 rows of data, Set # 238
# Extracting 1000 rows of data, Set # 239
# Extracting 1000 rows of data, Set # 240
# Extracting 1000 rows of data, Set # 241
# Extracting 1000 rows of data, Set # 242
# Extracting 1000 rows of data, Set # 243
# Extracting 1000 rows of data, Set # 244
# Extracting 1000 rows of data, Set # 245
# Extracting 1000 rows of data, Set # 246
# Extracting 1000 rows of data, Set # 247
# Extracting 1000 rows of data, Set # 248
# Extracting 1000 rows of data, Set # 249
# Extracting 1000 rows of data, Set # 250
# Extracting 1000 rows of data, Set # 251
# Extracting 1000 rows of data, Set # 252
# Extracting 1000 rows of data, Set # 253
# Extracting 1000 rows of data, Set # 254
# Extracting 1000 rows of data, Set # 255
# Extracting 1000 rows of data, Set # 256
# Extracting 1000 rows of data, Set # 257
# Extracting 1000 rows of data, Set # 258
# Extracting 1000 rows of data, Set # 259
# Extracting 1000 rows of data, Set # 260
# Extracting 1000 rows of data, Set # 261
# Extracting 1000 rows of data, Set # 262
# Extracting 1000 rows of data, Set # 263
# Extracting 1000 rows of data, Set # 264
# Extracting 1000 rows of data, Set # 265
# Extracting 1000 rows of data, Set # 266
# Extracting 1000 rows of data, Set # 267
# Extracting 1000 rows of data, Set # 268
# Extracting 1000 rows of data, Set # 269
# Extracting 1000 rows of data, Set # 270
# Extracting 1000 rows of data, Set # 271
# Extracting 1000 rows of data, Set # 272
# Extracting 1000 rows of data, Set # 273
# Extracting 1000 rows of data, Set # 274
# Extracting 1000 rows of data, Set # 275
# Extracting 1000 rows of data, Set # 276
# Extracting 1000 rows of data, Set # 277
# Extracting 1000 rows of data, Set # 278
# Extracting 1000 rows of data, Set # 279
# Extracting 1000 rows of data, Set # 280
# Extracting 1000 rows of data, Set # 281
# Extracting 1000 rows of data, Set # 282
# Extracting 1000 rows of data, Set # 283
# Extracting 1000 rows of data, Set # 284
# Extracting 1000 rows of data, Set # 285
# Extracting 1000 rows of data, Set # 286
# Extracting 1000 rows of data, Set # 287
# Extracting 1000 rows of data, Set # 288
# Extracting 1000 rows of data, Set # 289
# Extracting 1000 rows of data, Set # 290
# Extracting 1000 rows of data, Set # 291
# Extracting 1000 rows of data, Set # 292
# Extracting 1000 rows of data, Set # 293
# Extracting 1000 rows of data, Set # 294
# Extracting 1000 rows of data, Set # 295
# Extracting 1000 rows of data, Set # 296
# Extracting 1000 rows of data, Set # 297
# Extracting 1000 rows of data, Set # 298
# Extracting 1000 rows of data, Set # 299
# Extracting 1000 rows of data, Set # 300
# Extracting 1000 rows of data, Set # 301
# Extracting 1000 rows of data, Set # 302
# Extracting 1000 rows of data, Set # 303
# Extracting 1000 rows of data, Set # 304
# Extracting 1000 rows of data, Set # 305
# Extracting 1000 rows of data, Set # 306
# Extracting 1000 rows of data, Set # 307
# Extracting 1000 rows of data, Set # 308
# Extracting 1000 rows of data, Set # 309
# Extracting 1000 rows of data, Set # 310
# Extracting 1000 rows of data, Set # 311
# Extracting 1000 rows of data, Set # 312
# Extracting 1000 rows of data, Set # 313
# Extracting 1000 rows of data, Set # 314
# Extracting 1000 rows of data, Set # 315
# Extracting 1000 rows of data, Set # 316
# Extracting 1000 rows of data, Set # 317
# Extracting 1000 rows of data, Set # 318
# Extracting 1000 rows of data, Set # 319
# Extracting 1000 rows of data, Set # 320
# Extracting 1000 rows of data, Set # 321
# Extracting 1000 rows of data, Set # 322
# Extracting 1000 rows of data, Set # 323
# Extracting 1000 rows of data, Set # 324
# Extracting 1000 rows of data, Set # 325
# Extracting 1000 rows of data, Set # 326
# Extracting 1000 rows of data, Set # 327
# Extracting 1000 rows of data, Set # 328
# Extracting 1000 rows of data, Set # 329
# Extracting 1000 rows of data, Set # 330
# Extracting 1000 rows of data, Set # 331
# Extracting 1000 rows of data, Set # 332
# Extracting 1000 rows of data, Set # 333
# Extracting 1000 rows of data, Set # 334
# Extracting 1000 rows of data, Set # 335
# Extracting 1000 rows of data, Set # 336
# Extracting 1000 rows of data, Set # 337
# Extracting 1000 rows of data, Set # 338
# Extracting 1000 rows of data, Set # 339
# Extracting 1000 rows of data, Set # 340
# Extracting 1000 rows of data, Set # 341
# Extracting 1000 rows of data, Set # 342
# Extracting 1000 rows of data, Set # 343
# Extracting 1000 rows of data, Set # 344
# Extracting 1000 rows of data, Set # 345
# Extracting 1000 rows of data, Set # 346
# Extracting 1000 rows of data, Set # 347
# Extracting 1000 rows of data, Set # 348
# Extracting 1000 rows of data, Set # 349
# Extracting 1000 rows of data, Set # 350
# Extracting 1000 rows of data, Set # 351
# Extracting 1000 rows of data, Set # 352
# Extracting 1000 rows of data, Set # 353
# Extracting 1000 rows of data, Set # 354
# Extracting 1000 rows of data, Set # 355
# Extracting 1000 rows of data, Set # 356
# Extracting 1000 rows of data, Set # 357
# Extracting 1000 rows of data, Set # 358
# Extracting 1000 rows of data, Set # 359
# Extracting 1000 rows of data, Set # 360
# Extracting 1000 rows of data, Set # 361
# Extracting 1000 rows of data, Set # 362
# Extracting 1000 rows of data, Set # 363
# Extracting 1000 rows of data, Set # 364
# Extracting 1000 rows of data, Set # 365
# Extracting 1000 rows of data, Set # 366
# Extracting 1000 rows of data, Set # 367
# Extracting 1000 rows of data, Set # 368
# Extracting 1000 rows of data, Set # 369
# Extracting 1000 rows of data, Set # 370
# Extracting 1000 rows of data, Set # 371
# Extracting 1000 rows of data, Set # 372
# Extracting 1000 rows of data, Set # 373
# Extracting 1000 rows of data, Set # 374
# Extracting 1000 rows of data, Set # 375
# Extracting 1000 rows of data, Set # 376
# Extracting 1000 rows of data, Set # 377
# Extracting 1000 rows of data, Set # 378
# Extracting 1000 rows of data, Set # 379
# Extracting 1000 rows of data, Set # 380
# Extracting 1000 rows of data, Set # 381
# Extracting 1000 rows of data, Set # 382
# Extracting 1000 rows of data, Set # 383
# Extracting 1000 rows of data, Set # 384
# Extracting 1000 rows of data, Set # 385
# Extracting 1000 rows of data, Set # 386
# Extracting 1000 rows of data, Set # 387
# Extracting 1000 rows of data, Set # 388
# Extracting 1000 rows of data, Set # 389
# Extracting 1000 rows of data, Set # 390
# Extracting 1000 rows of data, Set # 391
# Extracting 1000 rows of data, Set # 392
# Extracting 1000 rows of data, Set # 393
# Extracting 1000 rows of data, Set # 394
# Extracting 1000 rows of data, Set # 395
# Extracting 1000 rows of data, Set # 396
# Extracting 1000 rows of data, Set # 397
# Extracting 1000 rows of data, Set # 398
# Extracting 1000 rows of data, Set # 399
# Extracting 1000 rows of data, Set # 400
# Extracting 1000 rows of data, Set # 401
# Extracting 1000 rows of data, Set # 402
# Extracting 1000 rows of data, Set # 403
# Extracting 1000 rows of data, Set # 404
# Extracting 1000 rows of data, Set # 405
# Extracting 1000 rows of data, Set # 406
# Extracting 1000 rows of data, Set # 407
# Extracting 1000 rows of data, Set # 408
# Extracting 1000 rows of data, Set # 409
# Extracting 1000 rows of data, Set # 410
# Extracting 1000 rows of data, Set # 411
# Extracting 1000 rows of data, Set # 412
# Extracting 1000 rows of data, Set # 413
# Extracting 1000 rows of data, Set # 414
# Extracting 1000 rows of data, Set # 415
# Extracting 1000 rows of data, Set # 416
# Extracting 1000 rows of data, Set # 417
# Extracting 1000 rows of data, Set # 418
# Extracting 1000 rows of data, Set # 419
# Extracting 1000 rows of data, Set # 420
# Extracting 1000 rows of data, Set # 421
# Extracting 1000 rows of data, Set # 422
# Extracting 1000 rows of data, Set # 423
# Extracting 1000 rows of data, Set # 424
# Extracting 1000 rows of data, Set # 425
# Extracting 1000 rows of data, Set # 426
# Extracting 1000 rows of data, Set # 427
# Extracting 1000 rows of data, Set # 428
# Extracting 1000 rows of data, Set # 429
# Extracting 1000 rows of data, Set # 430
# Extracting 1000 rows of data, Set # 431
# Extracting 1000 rows of data, Set # 432
# Extracting 1000 rows of data, Set # 433
# Extracting 1000 rows of data, Set # 434
# Extracting 1000 rows of data, Set # 435
# Extracting 1000 rows of data, Set # 436
# Extracting 1000 rows of data, Set # 437
# Extracting 1000 rows of data, Set # 438
# Extracting 1000 rows of data, Set # 439
# Extracting 1000 rows of data, Set # 440
# Extracting 1000 rows of data, Set # 441
# Extracting 1000 rows of data, Set # 442
# Extracting 1000 rows of data, Set # 443
# Extracting 1000 rows of data, Set # 444
# Extracting 1000 rows of data, Set # 445
# Extracting 1000 rows of data, Set # 446
# Extracting 1000 rows of data, Set # 447
# Extracting 1000 rows of data, Set # 448
# Extracting 1000 rows of data, Set # 449
# Extracting 1000 rows of data, Set # 450
# Extracting 1000 rows of data, Set # 451
# Extracting 1000 rows of data, Set # 452
# Extracting 1000 rows of data, Set # 453
# Extracting 1000 rows of data, Set # 454
# Extracting 1000 rows of data, Set # 455
# Extracting 1000 rows of data, Set # 456
# Extracting 1000 rows of data, Set # 457
# Extracting 1000 rows of data, Set # 458
# Extracting 1000 rows of data, Set # 459
# Extracting 1000 rows of data, Set # 460
# Extracting 1000 rows of data, Set # 461
# Extracting 1000 rows of data, Set # 462
# Extracting 1000 rows of data, Set # 463
# Extracting 1000 rows of data, Set # 464
# Extracting 1000 rows of data, Set # 465
# Extracting 1000 rows of data, Set # 466
# Extracting 1000 rows of data, Set # 467
# Extracting 1000 rows of data, Set # 468
# Extracting 1000 rows of data, Set # 469
# Extracting 1000 rows of data, Set # 470
# Extracting 1000 rows of data, Set # 471
# Extracting 1000 rows of data, Set # 472
# Extracting 1000 rows of data, Set # 473
# Extracting 1000 rows of data, Set # 474
# Extracting 1000 rows of data, Set # 475
# Extracting 1000 rows of data, Set # 476
# Extracting 1000 rows of data, Set # 477
# Extracting 1000 rows of data, Set # 478
# Extracting 1000 rows of data, Set # 479
# Extracting 1000 rows of data, Set # 480
# Extracting 1000 rows of data, Set # 481
# Extracting 1000 rows of data, Set # 482
# Extracting 1000 rows of data, Set # 483
# Extracting 1000 rows of data, Set # 484
# Extracting 1000 rows of data, Set # 485
# Extracting 1000 rows of data, Set # 486
# Extracting 1000 rows of data, Set # 487
# Extracting 1000 rows of data, Set # 488
# Extracting 1000 rows of data, Set # 489
# Extracting 1000 rows of data, Set # 490
# Extracting 1000 rows of data, Set # 491
# Extracting 1000 rows of data, Set # 492
# Extracting 1000 rows of data, Set # 493
# Extracting 1000 rows of data, Set # 494
# Extracting 1000 rows of data, Set # 495
# Extracting 1000 rows of data, Set # 496
# Extracting 1000 rows of data, Set # 497
# Extracting 1000 rows of data, Set # 498
# Extracting 1000 rows of data, Set # 499
# Extracting 1000 rows of data, Set # 500
# Extracting 1000 rows of data, Set # 501
# Extracting 1000 rows of data, Set # 502
# Extracting 1000 rows of data, Set # 503
# Extracting 1000 rows of data, Set # 504
# Extracting 1000 rows of data, Set # 505
# Extracting 1000 rows of data, Set # 506
# Extracting 1000 rows of data, Set # 507
# Extracting 1000 rows of data, Set # 508
# Extracting 1000 rows of data, Set # 509
# Extracting 1000 rows of data, Set # 510
# Extracting 1000 rows of data, Set # 511
# Extracting 1000 rows of data, Set # 512
# Extracting 1000 rows of data, Set # 513
# Extracting 1000 rows of data, Set # 514
# Extracting 1000 rows of data, Set # 515
# Extracting 1000 rows of data, Set # 516
# Extracting 1000 rows of data, Set # 517
# Extracting 1000 rows of data, Set # 518
# Extracting 1000 rows of data, Set # 519
# Extracting 1000 rows of data, Set # 520
# Extracting 1000 rows of data, Set # 521
# Extracting 1000 rows of data, Set # 522
# Extracting 1000 rows of data, Set # 523
# Extracting 1000 rows of data, Set # 524
# Extracting 1000 rows of data, Set # 525
# Extracting 1000 rows of data, Set # 526
# Extracting 1000 rows of data, Set # 527
# Extracting 1000 rows of data, Set # 528
# Extracting 1000 rows of data, Set # 529
# Extracting 1000 rows of data, Set # 530
# Extracting 1000 rows of data, Set # 531
# Extracting 1000 rows of data, Set # 532
# Extracting 1000 rows of data, Set # 533
# Extracting 1000 rows of data, Set # 534
# Extracting 1000 rows of data, Set # 535
# Extracting 1000 rows of data, Set # 536
# Extracting 1000 rows of data, Set # 537
# Extracting 1000 rows of data, Set # 538
# Extracting 1000 rows of data, Set # 539
# Extracting 1000 rows of data, Set # 540
# Extracting 1000 rows of data, Set # 541
# Extracting 1000 rows of data, Set # 542
# Extracting 1000 rows of data, Set # 543
# Extracting 1000 rows of data, Set # 544
# Extracting 1000 rows of data, Set # 545
# Extracting 1000 rows of data, Set # 546
# Extracting 1000 rows of data, Set # 547
# Extracting 1000 rows of data, Set # 548
# Extracting 1000 rows of data, Set # 549
# Extracting 1000 rows of data, Set # 550
# Extracting 1000 rows of data, Set # 551
# Extracting 1000 rows of data, Set # 552
# Extracting 1000 rows of data, Set # 553
# Extracting 1000 rows of data, Set # 554
# Extracting 1000 rows of data, Set # 555
# Extracting 1000 rows of data, Set # 556
# Extracting 1000 rows of data, Set # 557
# Extracting 1000 rows of data, Set # 558
# Extracting 1000 rows of data, Set # 559
# Extracting 1000 rows of data, Set # 560
# Extracting 1000 rows of data, Set # 561
# Extracting 1000 rows of data, Set # 562
# Extracting 1000 rows of data, Set # 563
# Extracting 1000 rows of data, Set # 564
# Extracting 1000 rows of data, Set # 565
# Extracting 1000 rows of data, Set # 566
# Extracting 1000 rows of data, Set # 567
# Extracting 1000 rows of data, Set # 568
# Extracting 1000 rows of data, Set # 569
# Extracting 1000 rows of data, Set # 570
# Extracting 1000 rows of data, Set # 571
# Extracting 1000 rows of data, Set # 572
# Extracting 1000 rows of data, Set # 573
# Extracting 1000 rows of data, Set # 574
# Extracting 1000 rows of data, Set # 575
# Extracting 1000 rows of data, Set # 576
# Extracting 1000 rows of data, Set # 577
# Extracting 1000 rows of data, Set # 578
# Extracting 1000 rows of data, Set # 579
# Extracting 1000 rows of data, Set # 580
# Extracting 1000 rows of data, Set # 581
# Extracting 1000 rows of data, Set # 582
# Extracting 1000 rows of data, Set # 583
# Extracting 1000 rows of data, Set # 584
# Extracting 1000 rows of data, Set # 585
# Extracting 1000 rows of data, Set # 586
# Extracting 1000 rows of data, Set # 587
# Extracting 1000 rows of data, Set # 588
# Extracting 1000 rows of data, Set # 589
# Extracting 1000 rows of data, Set # 590
# Extracting 1000 rows of data, Set # 591
# Extracting 1000 rows of data, Set # 592
# Extracting 1000 rows of data, Set # 593
# Extracting 1000 rows of data, Set # 594
# Extracting 1000 rows of data, Set # 595
# Extracting 1000 rows of data, Set # 596
# Extracting 1000 rows of data, Set # 597
# Extracting 1000 rows of data, Set # 598
# Extracting 1000 rows of data, Set # 599
# Extracting 1000 rows of data, Set # 600
# Extracting 1000 rows of data, Set # 601
# Extracting 1000 rows of data, Set # 602
# Extracting 1000 rows of data, Set # 603
# Extracting 1000 rows of data, Set # 604
# Extracting 1000 rows of data, Set # 605
# Extracting 1000 rows of data, Set # 606
# Extracting 1000 rows of data, Set # 607
# Extracting 1000 rows of data, Set # 608
# Extracting 1000 rows of data, Set # 609
# Extracting 1000 rows of data, Set # 610
# Extracting 1000 rows of data, Set # 611
# Extracting 1000 rows of data, Set # 612
# Extracting 1000 rows of data, Set # 613
# Extracting 1000 rows of data, Set # 614
# Extracting 1000 rows of data, Set # 615
# Extracting 1000 rows of data, Set # 616
# Extracting 1000 rows of data, Set # 617
# Extracting 1000 rows of data, Set # 618
# Extracting 1000 rows of data, Set # 619
# Extracting 1000 rows of data, Set # 620
# Extracting 1000 rows of data, Set # 621
# Extracting 1000 rows of data, Set # 622
# Extracting 1000 rows of data, Set # 623
# Extracting 1000 rows of data, Set # 624
# Extracting 1000 rows of data, Set # 625
# Extracting 1000 rows of data, Set # 626
# Extracting 1000 rows of data, Set # 627
# Extracting 1000 rows of data, Set # 628
# Extracting 1000 rows of data, Set # 629
# Extracting 1000 rows of data, Set # 630
# Extracting 1000 rows of data, Set # 631
# Extracting 1000 rows of data, Set # 632
# Extracting 1000 rows of data, Set # 633
# Extracting 1000 rows of data, Set # 634
# Extracting 1000 rows of data, Set # 635
# Extracting 1000 rows of data, Set # 636
# Extracting 1000 rows of data, Set # 637
# Extracting 1000 rows of data, Set # 638
# Extracting 1000 rows of data, Set # 639
# Extracting 1000 rows of data, Set # 640
# Extracting 1000 rows of data, Set # 641
# Extracting 1000 rows of data, Set # 642
# Extracting 1000 rows of data, Set # 643
# Extracting 1000 rows of data, Set # 644
# Extracting 1000 rows of data, Set # 645
# Extracting 1000 rows of data, Set # 646
# Extracting 1000 rows of data, Set # 647
# Extracting 1000 rows of data, Set # 648
# Extracting 1000 rows of data, Set # 649
# Extracting 1000 rows of data, Set # 650
# Extracting 1000 rows of data, Set # 651
# Extracting 1000 rows of data, Set # 652
# Extracting 1000 rows of data, Set # 653
# Extracting 1000 rows of data, Set # 654
# Extracting 1000 rows of data, Set # 655
# Extracting 1000 rows of data, Set # 656
# Extracting 1000 rows of data, Set # 657
# Extracting 1000 rows of data, Set # 658
# Extracting 1000 rows of data, Set # 659
# Extracting 1000 rows of data, Set # 660
# Extracting 1000 rows of data, Set # 661
# Extracting 1000 rows of data, Set # 662
# Extracting 1000 rows of data, Set # 663
# Extracting 1000 rows of data, Set # 664
# Extracting 1000 rows of data, Set # 665
# Extracting 1000 rows of data, Set # 666
# Extracting 1000 rows of data, Set # 667
# Extracting 1000 rows of data, Set # 668
# Extracting 1000 rows of data, Set # 669
# Extracting 1000 rows of data, Set # 670
# Extracting 1000 rows of data, Set # 671
# Extracting 1000 rows of data, Set # 672
# Extracting 1000 rows of data, Set # 673
# Extracting 1000 rows of data, Set # 674
# Extracting 1000 rows of data, Set # 675
# Extracting 1000 rows of data, Set # 676
# Extracting 1000 rows of data, Set # 677
# Extracting 1000 rows of data, Set # 678
# Extracting 1000 rows of data, Set # 679
# Extracting 1000 rows of data, Set # 680
# Extracting 1000 rows of data, Set # 681
# Extracting 1000 rows of data, Set # 682
# Extracting 1000 rows of data, Set # 683
# Extracting 1000 rows of data, Set # 684
# Extracting 1000 rows of data, Set # 685
# Extracting 1000 rows of data, Set # 686
# Extracting 1000 rows of data, Set # 687
# Extracting 1000 rows of data, Set # 688
# Extracting 1000 rows of data, Set # 689
# Extracting 1000 rows of data, Set # 690
# Extracting 1000 rows of data, Set # 691
# Extracting 1000 rows of data, Set # 692
# Extracting 1000 rows of data, Set # 693
# Extracting 1000 rows of data, Set # 694
# Extracting 1000 rows of data, Set # 695
# Extracting 1000 rows of data, Set # 696
# Extracting 1000 rows of data, Set # 697
# Extracting 1000 rows of data, Set # 698
# Extracting 1000 rows of data, Set # 699
# Extracting 1000 rows of data, Set # 700
# Extracting 1000 rows of data, Set # 701
# Extracting 1000 rows of data, Set # 702
# Extracting 1000 rows of data, Set # 703
# Extracting 1000 rows of data, Set # 704
# Extracting 1000 rows of data, Set # 705
# Extracting 1000 rows of data, Set # 706
# Extracting 1000 rows of data, Set # 707
# Extracting 1000 rows of data, Set # 708
# Extracting 1000 rows of data, Set # 709
# Extracting 1000 rows of data, Set # 710
# Extracting 1000 rows of data, Set # 711
# Extracting 1000 rows of data, Set # 712
# Extracting 1000 rows of data, Set # 713
# Extracting 1000 rows of data, Set # 714
# Extracting 1000 rows of data, Set # 715
# Extracting 1000 rows of data, Set # 716
# Extracting 1000 rows of data, Set # 717
# Extracting 1000 rows of data, Set # 718
# Extracting 1000 rows of data, Set # 719
# Extracting 1000 rows of data, Set # 720
# Extracting 1000 rows of data, Set # 721
# Extracting 1000 rows of data, Set # 722
# Extracting 1000 rows of data, Set # 723
# Extracting 1000 rows of data, Set # 724
# Extracting 1000 rows of data, Set # 725
# Extracting 1000 rows of data, Set # 726
# Extracting 1000 rows of data, Set # 727
# Extracting 1000 rows of data, Set # 728
# Extracting 1000 rows of data, Set # 729
# Extracting 1000 rows of data, Set # 730
# Extracting 1000 rows of data, Set # 731
# Extracting 1000 rows of data, Set # 732
# Extracting 1000 rows of data, Set # 733
# Extracting 1000 rows of data, Set # 734
# Extracting 1000 rows of data, Set # 735
# Extracting 1000 rows of data, Set # 736
# Extracting 1000 rows of data, Set # 737
# Extracting 1000 rows of data, Set # 738
# Extracting 1000 rows of data, Set # 739
# Extracting 1000 rows of data, Set # 740
# Extracting 1000 rows of data, Set # 741
# Extracting 1000 rows of data, Set # 742
# Extracting 1000 rows of data, Set # 743
# Extracting 1000 rows of data, Set # 744
# Extracting 1000 rows of data, Set # 745
# Extracting 1000 rows of data, Set # 746
# Extracting 1000 rows of data, Set # 747
# Extracting 1000 rows of data, Set # 748
# Extracting 1000 rows of data, Set # 749
# Extracting 1000 rows of data, Set # 750
# Extracting 1000 rows of data, Set # 751
# Extracting 1000 rows of data, Set # 752
# Extracting 1000 rows of data, Set # 753
# Extracting 1000 rows of data, Set # 754
# Extracting 1000 rows of data, Set # 755
# Extracting 1000 rows of data, Set # 756
# Extracting 1000 rows of data, Set # 757
# Extracting 1000 rows of data, Set # 758
# Extracting 1000 rows of data, Set # 759
# Extracting 1000 rows of data, Set # 760
# Extracting 1000 rows of data, Set # 761
# Extracting 1000 rows of data, Set # 762
# Extracting 1000 rows of data, Set # 763
# Extracting 1000 rows of data, Set # 764
# Extracting 1000 rows of data, Set # 765
# Extracting 1000 rows of data, Set # 766
# Extracting 1000 rows of data, Set # 767
# Extracting 1000 rows of data, Set # 768
# Extracting 1000 rows of data, Set # 769
# Extracting 1000 rows of data, Set # 770
# Extracting 1000 rows of data, Set # 771
# Extracting 1000 rows of data, Set # 772
# Extracting 1000 rows of data, Set # 773
# Extracting 1000 rows of data, Set # 774
# Extracting 1000 rows of data, Set # 775
# Extracting 1000 rows of data, Set # 776
# Extracting 1000 rows of data, Set # 777
# Extracting 1000 rows of data, Set # 778
# Extracting 1000 rows of data, Set # 779
# Extracting 1000 rows of data, Set # 780
# Extracting 1000 rows of data, Set # 781
# Extracting 1000 rows of data, Set # 782
# Extracting 1000 rows of data, Set # 783
# Extracting 1000 rows of data, Set # 784
# Extracting 1000 rows of data, Set # 785
# Extracting 1000 rows of data, Set # 786
# Extracting 1000 rows of data, Set # 787
# Extracting 1000 rows of data, Set # 788
# Extracting 1000 rows of data, Set # 789
# Extracting 1000 rows of data, Set # 790
# Extracting 1000 rows of data, Set # 791
# Extracting 1000 rows of data, Set # 792
# Extracting 1000 rows of data, Set # 793
# Extracting 1000 rows of data, Set # 794
# Extracting 1000 rows of data, Set # 795
# Extracting 1000 rows of data, Set # 796
# Extracting 1000 rows of data, Set # 797
# Extracting 1000 rows of data, Set # 798
# Extracting 1000 rows of data, Set # 799
# Extracting 1000 rows of data, Set # 800
# Extracting 1000 rows of data, Set # 801
# Extracting 1000 rows of data, Set # 802
# Extracting 1000 rows of data, Set # 803
# Extracting 1000 rows of data, Set # 804
# Extracting 1000 rows of data, Set # 805
# Extracting 1000 rows of data, Set # 806
# Extracting 1000 rows of data, Set # 807
# Extracting 1000 rows of data, Set # 808
# Extracting 1000 rows of data, Set # 809
# Extracting 1000 rows of data, Set # 810
# Extracting 1000 rows of data, Set # 811
# Extracting 1000 rows of data, Set # 812
# Extracting 1000 rows of data, Set # 813
# Extracting 1000 rows of data, Set # 814
# Extracting 1000 rows of data, Set # 815
# Extracting 1000 rows of data, Set # 816
# Extracting 1000 rows of data, Set # 817
# Extracting 1000 rows of data, Set # 818
# Extracting 1000 rows of data, Set # 819
# Extracting 1000 rows of data, Set # 820
# Extracting 1000 rows of data, Set # 821
# Extracting 1000 rows of data, Set # 822
# Extracting 1000 rows of data, Set # 823
# Extracting 1000 rows of data, Set # 824
# Extracting 1000 rows of data, Set # 825
# Extracting 1000 rows of data, Set # 826
# Extracting 1000 rows of data, Set # 827
# Extracting 1000 rows of data, Set # 828
# Extracting 1000 rows of data, Set # 829
# Extracting 1000 rows of data, Set # 830
# Extracting 1000 rows of data, Set # 831
# Extracting 1000 rows of data, Set # 832
# Extracting 1000 rows of data, Set # 833
# Extracting 1000 rows of data, Set # 834
# Extracting 1000 rows of data, Set # 835
# Extracting 1000 rows of data, Set # 836
# Extracting 1000 rows of data, Set # 837
# Extracting 1000 rows of data, Set # 838
# Extracting 1000 rows of data, Set # 839
# Extracting 1000 rows of data, Set # 840
# Extracting 1000 rows of data, Set # 841
# Extracting 1000 rows of data, Set # 842
# Extracting 1000 rows of data, Set # 843
# Extracting 1000 rows of data, Set # 844
# Extracting 1000 rows of data, Set # 845
# Extracting 1000 rows of data, Set # 846
# Extracting 1000 rows of data, Set # 847
# Extracting 1000 rows of data, Set # 848
# Extracting 1000 rows of data, Set # 849
# Extracting 1000 rows of data, Set # 850
# Extracting 1000 rows of data, Set # 851
# Extracting 1000 rows of data, Set # 852
# Extracting 1000 rows of data, Set # 853
# Extracting 1000 rows of data, Set # 854
# Extracting 1000 rows of data, Set # 855
# Extracting 1000 rows of data, Set # 856
# Extracting 1000 rows of data, Set # 857
# Extracting 1000 rows of data, Set # 858
# Extracting 1000 rows of data, Set # 859
# Extracting 1000 rows of data, Set # 860
# Extracting 1000 rows of data, Set # 861
# Extracting 1000 rows of data, Set # 862
# Extracting 1000 rows of data, Set # 863
# Extracting 1000 rows of data, Set # 864
# Extracting 1000 rows of data, Set # 865
# Extracting 1000 rows of data, Set # 866
# Extracting 1000 rows of data, Set # 867
# Extracting 1000 rows of data, Set # 868
# Extracting 1000 rows of data, Set # 869
# Extracting 1000 rows of data, Set # 870
# Extracting 1000 rows of data, Set # 871
# Extracting 1000 rows of data, Set # 872
# Extracting 1000 rows of data, Set # 873
# Extracting 1000 rows of data, Set # 874
# Extracting 1000 rows of data, Set # 875
# Extracting 1000 rows of data, Set # 876
# Extracting 1000 rows of data, Set # 877
# Extracting 1000 rows of data, Set # 878
# Extracting 1000 rows of data, Set # 879
# Extracting 1000 rows of data, Set # 880
# Extracting 1000 rows of data, Set # 881
# Extracting 1000 rows of data, Set # 882
# Extracting 1000 rows of data, Set # 883
# Extracting 1000 rows of data, Set # 884
# Extracting 1000 rows of data, Set # 885
# Extracting 1000 rows of data, Set # 886
# Extracting 1000 rows of data, Set # 887
# Extracting 1000 rows of data, Set # 888
# Extracting 1000 rows of data, Set # 889
# Extracting 1000 rows of data, Set # 890
# Extracting 1000 rows of data, Set # 891
# Extracting 1000 rows of data, Set # 892
# Extracting 1000 rows of data, Set # 893
# Extracting 1000 rows of data, Set # 894
# Extracting 1000 rows of data, Set # 895
# Extracting 1000 rows of data, Set # 896
# Extracting 1000 rows of data, Set # 897
# Extracting 1000 rows of data, Set # 898
# Extracting 1000 rows of data, Set # 899
# Extracting 1000 rows of data, Set # 900
# Extracting 1000 rows of data, Set # 901
# Extracting 1000 rows of data, Set # 902
# Extracting 1000 rows of data, Set # 903
# Extracting 1000 rows of data, Set # 904
# Extracting 1000 rows of data, Set # 905
# Extracting 1000 rows of data, Set # 906
# Extracting 1000 rows of data, Set # 907
# Extracting 1000 rows of data, Set # 908
# Extracting 1000 rows of data, Set # 909
# Extracting 1000 rows of data, Set # 910
# Extracting 1000 rows of data, Set # 911
# Extracting 1000 rows of data, Set # 912
# Extracting 1000 rows of data, Set # 913
# Extracting 1000 rows of data, Set # 914
# Extracting 1000 rows of data, Set # 915
# Extracting 1000 rows of data, Set # 916
# Extracting 1000 rows of data, Set # 917
# Extracting 1000 rows of data, Set # 918
# Extracting 1000 rows of data, Set # 919
# Extracting 1000 rows of data, Set # 920
# Extracting 1000 rows of data, Set # 921
# Extracting 1000 rows of data, Set # 922
# Extracting 1000 rows of data, Set # 923
# Extracting 1000 rows of data, Set # 924
# Extracting 1000 rows of data, Set # 925
# Extracting 1000 rows of data, Set # 926
# Extracting 1000 rows of data, Set # 927
# Extracting 1000 rows of data, Set # 928
# Extracting 1000 rows of data, Set # 929
# Extracting 1000 rows of data, Set # 930
# Extracting 1000 rows of data, Set # 931
# Extracting 1000 rows of data, Set # 932
# Extracting 1000 rows of data, Set # 933
# Extracting 1000 rows of data, Set # 934
# Extracting 1000 rows of data, Set # 935
# Extracting 1000 rows of data, Set # 936
# Extracting 1000 rows of data, Set # 937
# Extracting 1000 rows of data, Set # 938
# Extracting 1000 rows of data, Set # 939
# Extracting 1000 rows of data, Set # 940
# Extracting 1000 rows of data, Set # 941
# Extracting 1000 rows of data, Set # 942
# Extracting 1000 rows of data, Set # 943
# Extracting 1000 rows of data, Set # 944
# Extracting 1000 rows of data, Set # 945
# Extracting 1000 rows of data, Set # 946
# Extracting 1000 rows of data, Set # 947
# Extracting 1000 rows of data, Set # 948
# Extracting 1000 rows of data, Set # 949
# Extracting 1000 rows of data, Set # 950
# Extracting 1000 rows of data, Set # 951
# Extracting 1000 rows of data, Set # 952
# Extracting 1000 rows of data, Set # 953
# Extracting 1000 rows of data, Set # 954
# Extracting 1000 rows of data, Set # 955
# Extracting 1000 rows of data, Set # 956
# Extracting 1000 rows of data, Set # 957
# Extracting 1000 rows of data, Set # 958
# Extracting 1000 rows of data, Set # 959
# Extracting 1000 rows of data, Set # 960
# Extracting 1000 rows of data, Set # 961
# Extracting 1000 rows of data, Set # 962
# Extracting 1000 rows of data, Set # 963
# Extracting 1000 rows of data, Set # 964
# Extracting 1000 rows of data, Set # 965
# Extracting 1000 rows of data, Set # 966
# Extracting 1000 rows of data, Set # 967
# Extracting 1000 rows of data, Set # 968
# Extracting 1000 rows of data, Set # 969
# Extracting 1000 rows of data, Set # 970
# Extracting 1000 rows of data, Set # 971
# Extracting 1000 rows of data, Set # 972
# Extracting 1000 rows of data, Set # 973
# Extracting 1000 rows of data, Set # 974
# Extracting 1000 rows of data, Set # 975
# Extracting 1000 rows of data, Set # 976
# Extracting 1000 rows of data, Set # 977
# Extracting 1000 rows of data, Set # 978
# Extracting 1000 rows of data, Set # 979
# Extracting 1000 rows of data, Set # 980
# Extracting 1000 rows of data, Set # 981
# Extracting 1000 rows of data, Set # 982
# Extracting 1000 rows of data, Set # 983
# Extracting 1000 rows of data, Set # 984
# Extracting 1000 rows of data, Set # 985
# Extracting 1000 rows of data, Set # 986
# Extracting 1000 rows of data, Set # 987
# Extracting 1000 rows of data, Set # 988
# Extracting 1000 rows of data, Set # 989
# Extracting 1000 rows of data, Set # 990
# Extracting 1000 rows of data, Set # 991
# Extracting 1000 rows of data, Set # 992
# Extracting 1000 rows of data, Set # 993
# Extracting 1000 rows of data, Set # 994
# Extracting 1000 rows of data, Set # 995
# Extracting 1000 rows of data, Set # 996
# Extracting 1000 rows of data, Set # 997
# Extracting 1000 rows of data, Set # 998
# Extracting 1000 rows of data, Set # 999
# Extracting 1000 rows of data, Set # 1000
# Extracting 1000 rows of data, Set # 1001
# Extracting 1000 rows of data, Set # 1002
# Extracting 1000 rows of data, Set # 1003
# Extracting 1000 rows of data, Set # 1004
# Extracting 1000 rows of data, Set # 1005
# Extracting 1000 rows of data, Set # 1006
# Extracting 1000 rows of data, Set # 1007
# Extracting 1000 rows of data, Set # 1008
# Extracting 1000 rows of data, Set # 1009
# Extracting 1000 rows of data, Set # 1010
# Extracting 1000 rows of data, Set # 1011
# Extracting 1000 rows of data, Set # 1012
# Extracting 1000 rows of data, Set # 1013
# Extracting 1000 rows of data, Set # 1014
# Extracting 1000 rows of data, Set # 1015
# Extracting 1000 rows of data, Set # 1016
# Extracting 1000 rows of data, Set # 1017
# Extracting 1000 rows of data, Set # 1018
# Extracting 1000 rows of data, Set # 1019
# Extracting 1000 rows of data, Set # 1020
# Extracting 1000 rows of data, Set # 1021
# Extracting 1000 rows of data, Set # 1022
# Extracting 1000 rows of data, Set # 1023
# Extracting 1000 rows of data, Set # 1024
# Extracting 1000 rows of data, Set # 1025
# Extracting 1000 rows of data, Set # 1026
# Extracting 1000 rows of data, Set # 1027
# Extracting 1000 rows of data, Set # 1028
# Extracting 1000 rows of data, Set # 1029
# Extracting 1000 rows of data, Set # 1030
# Extracting 1000 rows of data, Set # 1031
# Extracting 1000 rows of data, Set # 1032
# Extracting 1000 rows of data, Set # 1033
# Extracting 1000 rows of data, Set # 1034
# Extracting 1000 rows of data, Set # 1035
# Extracting 1000 rows of data, Set # 1036
# Extracting 1000 rows of data, Set # 1037
# Extracting 1000 rows of data, Set # 1038
# Extracting 1000 rows of data, Set # 1039
# Extracting 1000 rows of data, Set # 1040
# Extracting 1000 rows of data, Set # 1041
# Extracting 1000 rows of data, Set # 1042
# Extracting 1000 rows of data, Set # 1043
# Extracting 1000 rows of data, Set # 1044
# Extracting 1000 rows of data, Set # 1045
# Extracting 1000 rows of data, Set # 1046
# Extracting 1000 rows of data, Set # 1047
# Extracting 1000 rows of data, Set # 1048
# Extracting 1000 rows of data, Set # 1049
# Extracting 1000 rows of data, Set # 1050
# Extracting 1000 rows of data, Set # 1051
# Extracting 1000 rows of data, Set # 1052
# Extracting 1000 rows of data, Set # 1053
# Extracting 1000 rows of data, Set # 1054
# Extracting 1000 rows of data, Set # 1055
# Extracting 1000 rows of data, Set # 1056
# Extracting 1000 rows of data, Set # 1057
# Extracting 1000 rows of data, Set # 1058
# Extracting 1000 rows of data, Set # 1059
# Extracting 1000 rows of data, Set # 1060
# Extracting 1000 rows of data, Set # 1061
# Extracting 1000 rows of data, Set # 1062
# Extracting 1000 rows of data, Set # 1063
# Extracting 1000 rows of data, Set # 1064
# Extracting 1000 rows of data, Set # 1065
# Extracting 1000 rows of data, Set # 1066
# Extracting 1000 rows of data, Set # 1067
# Extracting 1000 rows of data, Set # 1068
# Extracting 1000 rows of data, Set # 1069
# Extracting 1000 rows of data, Set # 1070
# Extracting 1000 rows of data, Set # 1071
# Extracting 1000 rows of data, Set # 1072
# Extracting 1000 rows of data, Set # 1073
# Extracting 1000 rows of data, Set # 1074
# Extracting 1000 rows of data, Set # 1075
# Extracting 1000 rows of data, Set # 1076
# Extracting 1000 rows of data, Set # 1077
# Extracting 1000 rows of data, Set # 1078
# Extracting 1000 rows of data, Set # 1079
# Extracting 1000 rows of data, Set # 1080
# Extracting 1000 rows of data, Set # 1081
# Extracting 1000 rows of data, Set # 1082
# Extracting 1000 rows of data, Set # 1083
# Extracting 1000 rows of data, Set # 1084
# Extracting 1000 rows of data, Set # 1085
# Extracting 1000 rows of data, Set # 1086
# Extracting 1000 rows of data, Set # 1087
# Extracting 1000 rows of data, Set # 1088
# Extracting 1000 rows of data, Set # 1089
# Extracting 1000 rows of data, Set # 1090
# Extracting 1000 rows of data, Set # 1091
# Extracting 1000 rows of data, Set # 1092
# Extracting 1000 rows of data, Set # 1093
# Extracting 1000 rows of data, Set # 1094
# Extracting 1000 rows of data, Set # 1095
# Extracting 1000 rows of data, Set # 1096
# Extracting 1000 rows of data, Set # 1097
# Extracting 1000 rows of data, Set # 1098
# Extracting 1000 rows of data, Set # 1099
# Extracting 1000 rows of data, Set # 1100
# Extracting 1000 rows of data, Set # 1101
# Extracting 1000 rows of data, Set # 1102
# Extracting 1000 rows of data, Set # 1103
# Extracting 1000 rows of data, Set # 1104
# Extracting 1000 rows of data, Set # 1105
# Extracting 1000 rows of data, Set # 1106
# Extracting 1000 rows of data, Set # 1107
# Extracting 1000 rows of data, Set # 1108
# Extracting 1000 rows of data, Set # 1109
# Extracting 1000 rows of data, Set # 1110
# Extracting 1000 rows of data, Set # 1111
# Extracting 1000 rows of data, Set # 1112
# Extracting 1000 rows of data, Set # 1113
# Extracting 1000 rows of data, Set # 1114
# Extracting 1000 rows of data, Set # 1115
# Extracting 1000 rows of data, Set # 1116
# Extracting 1000 rows of data, Set # 1117
# Extracting 1000 rows of data, Set # 1118
# Extracting 1000 rows of data, Set # 1119
# Extracting 1000 rows of data, Set # 1120
# Extracting 1000 rows of data, Set # 1121
# Extracting 1000 rows of data, Set # 1122
# Extracting 1000 rows of data, Set # 1123
# Extracting 1000 rows of data, Set # 1124
# Extracting 1000 rows of data, Set # 1125
# Extracting 1000 rows of data, Set # 1126
# Extracting 1000 rows of data, Set # 1127
# Extracting 1000 rows of data, Set # 1128
# Extracting 1000 rows of data, Set # 1129
# Extracting 1000 rows of data, Set # 1130
# Extracting 1000 rows of data, Set # 1131
# Extracting 1000 rows of data, Set # 1132
# Extracting 1000 rows of data, Set # 1133
# Extracting 1000 rows of data, Set # 1134
# Extracting 1000 rows of data, Set # 1135
# Extracting 1000 rows of data, Set # 1136
# Extracting 1000 rows of data, Set # 1137
# Extracting 1000 rows of data, Set # 1138
# Extracting 1000 rows of data, Set # 1139
# Extracting 1000 rows of data, Set # 1140
# Extracting 1000 rows of data, Set # 1141
# Extracting 1000 rows of data, Set # 1142
# Extracting 1000 rows of data, Set # 1143
# Extracting 1000 rows of data, Set # 1144
# Extracting 1000 rows of data, Set # 1145
# Extracting 1000 rows of data, Set # 1146
# Extracting 1000 rows of data, Set # 1147
# Extracting 1000 rows of data, Set # 1148
# Extracting 1000 rows of data, Set # 1149
# Extracting 1000 rows of data, Set # 1150
# Extracting 1000 rows of data, Set # 1151
# Extracting 1000 rows of data, Set # 1152
# Extracting 1000 rows of data, Set # 1153
# Extracting 1000 rows of data, Set # 1154
# Extracting 1000 rows of data, Set # 1155
# Extracting 1000 rows of data, Set # 1156
# Extracting 1000 rows of data, Set # 1157
# Extracting 1000 rows of data, Set # 1158
# Extracting 1000 rows of data, Set # 1159
# Extracting 1000 rows of data, Set # 1160
# Extracting 1000 rows of data, Set # 1161
# Extracting 1000 rows of data, Set # 1162
# Extracting 1000 rows of data, Set # 1163
# Extracting 1000 rows of data, Set # 1164
# Extracting 1000 rows of data, Set # 1165
# Extracting 1000 rows of data, Set # 1166
# Extracting 1000 rows of data, Set # 1167
# Extracting 1000 rows of data, Set # 1168
# Extracting 1000 rows of data, Set # 1169
# Extracting 1000 rows of data, Set # 1170
# Extracting 1000 rows of data, Set # 1171
# Extracting 1000 rows of data, Set # 1172
# Extracting 1000 rows of data, Set # 1173
# Extracting 1000 rows of data, Set # 1174
# Extracting 1000 rows of data, Set # 1175
# Extracting 1000 rows of data, Set # 1176
# Extracting 1000 rows of data, Set # 1177
# Extracting 1000 rows of data, Set # 1178
# Extracting 1000 rows of data, Set # 1179
# Extracting 1000 rows of data, Set # 1180
# Extracting 1000 rows of data, Set # 1181
# Extracting 1000 rows of data, Set # 1182
# Extracting 1000 rows of data, Set # 1183
# Extracting 1000 rows of data, Set # 1184
# Extracting 1000 rows of data, Set # 1185
# Extracting 1000 rows of data, Set # 1186
# Extracting 1000 rows of data, Set # 1187
# Extracting 1000 rows of data, Set # 1188
# Extracting 1000 rows of data, Set # 1189
# Extracting 1000 rows of data, Set # 1190
# Extracting 1000 rows of data, Set # 1191
# Extracting 1000 rows of data, Set # 1192
# Extracting 1000 rows of data, Set # 1193
# Extracting 1000 rows of data, Set # 1194
# Extracting 1000 rows of data, Set # 1195
# Extracting 1000 rows of data, Set # 1196
# Extracting 1000 rows of data, Set # 1197
# Extracting 1000 rows of data, Set # 1198
# Extracting 1000 rows of data, Set # 1199
# Extracting 1000 rows of data, Set # 1200
# Extracting 1000 rows of data, Set # 1201
# Extracting 1000 rows of data, Set # 1202
# Extracting 1000 rows of data, Set # 1203
# Extracting 1000 rows of data, Set # 1204
# Extracting 1000 rows of data, Set # 1205
# Extracting 1000 rows of data, Set # 1206
# Extracting 1000 rows of data, Set # 1207
# Extracting 1000 rows of data, Set # 1208
# Extracting 1000 rows of data, Set # 1209
# Extracting 1000 rows of data, Set # 1210
# Extracting 1000 rows of data, Set # 1211
# Extracting 1000 rows of data, Set # 1212
# Extracting 1000 rows of data, Set # 1213
# Extracting 1000 rows of data, Set # 1214
# Extracting 1000 rows of data, Set # 1215
# Extracting 1000 rows of data, Set # 1216
# Extracting 1000 rows of data, Set # 1217
# Extracting 1000 rows of data, Set # 1218
# Extracting 1000 rows of data, Set # 1219
# Extracting 1000 rows of data, Set # 1220
# Extracting 1000 rows of data, Set # 1221
# Extracting 1000 rows of data, Set # 1222
# Extracting 1000 rows of data, Set # 1223
# Extracting 1000 rows of data, Set # 1224
# Extracting 1000 rows of data, Set # 1225
# Extracting 1000 rows of data, Set # 1226
# Extracting 1000 rows of data, Set # 1227
# Extracting 1000 rows of data, Set # 1228
# Extracting 1000 rows of data, Set # 1229
# Extracting 1000 rows of data, Set # 1230
# Extracting 1000 rows of data, Set # 1231
# Extracting 1000 rows of data, Set # 1232
# Extracting 1000 rows of data, Set # 1233
# Extracting 1000 rows of data, Set # 1234
# Extracting 1000 rows of data, Set # 1235
# Extracting 1000 rows of data, Set # 1236
# Extracting 1000 rows of data, Set # 1237
# Extracting 1000 rows of data, Set # 1238
# Extracting 1000 rows of data, Set # 1239
# Extracting 1000 rows of data, Set # 1240
# Extracting 1000 rows of data, Set # 1241
# Extracting 1000 rows of data, Set # 1242
# Extracting 1000 rows of data, Set # 1243
# Extracting 1000 rows of data, Set # 1244
# Extracting 1000 rows of data, Set # 1245
# Extracting 1000 rows of data, Set # 1246
# Extracting 1000 rows of data, Set # 1247
# Extracting 1000 rows of data, Set # 1248
# Extracting 1000 rows of data, Set # 1249
# Extracting 1000 rows of data, Set # 1250
# Extracting 1000 rows of data, Set # 1251
# Extracting 1000 rows of data, Set # 1252
# Extracting 1000 rows of data, Set # 1253
# Extracting 1000 rows of data, Set # 1254
# Extracting 1000 rows of data, Set # 1255
# Extracting 1000 rows of data, Set # 1256
# Extracting 1000 rows of data, Set # 1257
# Extracting 1000 rows of data, Set # 1258
# Extracting 1000 rows of data, Set # 1259
# Extracting 1000 rows of data, Set # 1260
# Extracting 1000 rows of data, Set # 1261
# Extracting 1000 rows of data, Set # 1262
# Extracting 1000 rows of data, Set # 1263
# Extracting 1000 rows of data, Set # 1264
# Extracting 1000 rows of data, Set # 1265
# Extracting 1000 rows of data, Set # 1266
# Extracting 1000 rows of data, Set # 1267
# Extracting 1000 rows of data, Set # 1268
# Extracting 1000 rows of data, Set # 1269
# Extracting 1000 rows of data, Set # 1270
# Extracting 1000 rows of data, Set # 1271
# Extracting 1000 rows of data, Set # 1272
# Extracting 1000 rows of data, Set # 1273
# Extracting 1000 rows of data, Set # 1274
# Extracting 1000 rows of data, Set # 1275
# Extracting 1000 rows of data, Set # 1276
# Extracting 1000 rows of data, Set # 1277
# Extracting 1000 rows of data, Set # 1278
# Extracting 1000 rows of data, Set # 1279
# Extracting 1000 rows of data, Set # 1280
# Extracting 579 rows of data, Set # 1281
# Extracting 0 rows of data, Set # 1282
# Total number of records extracted: 1280579

# %%
# Create DataFrame
crime_df = pd.DataFrame(data_list)

# %%
# DataFrame info
crime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1280579 entries, 0 to 1280578
# Data columns (total 8 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   Complaint_No  1280579 non-null  object
#  1   Reported_Dt   1280579 non-null  object
#  2   Borough_Name  1280579 non-null  object
#  3   Ofns_Desc     1280579 non-null  object
#  4   PD_Desc       1280579 non-null  object
#  5   Law_Cat       1280579 non-null  object
#  6   Latitude      1280576 non-null  object
#  7   Longitude     1280576 non-null  object
# dtypes: object(8)
# memory usage: 78.2+ MB

# %%
# Drop rows with null values
cleaned_crime_df = crime_df.dropna()

# %%
# Preview DataFrame
cleaned_crime_df.head(10)
# Out:
#         Complaint_No Reported_Dt Borough_Name                       Ofns_Desc  \
# 1139070     88397298  2013-01-01    MANHATTAN        VEHICLE AND TRAFFIC LAWS
# 1138649     88378509  2013-01-01    MANHATTAN    ASSAULT 3 & RELATED OFFENSES
# 1138648     88378508  2013-01-01    MANHATTAN  INTOXICATED & IMPAIRED DRIVING
# 1138647     88378506  2013-01-01    MANHATTAN    ASSAULT 3 & RELATED OFFENSES
# 1138646     88378505  2013-01-01    MANHATTAN                   PETIT LARCENY
# 1139066     88397294  2013-01-01    MANHATTAN    ASSAULT 3 & RELATED OFFENSES
# 1139069     88397297  2013-01-01    MANHATTAN    ASSAULT 3 & RELATED OFFENSES
# 1139073     88397307  2013-01-01    MANHATTAN        VEHICLE AND TRAFFIC LAWS
# 1139082     88400523  2013-01-01    MANHATTAN  OFFENSES AGAINST PUBLIC ADMINI
# 1138650     88378511  2013-01-01    MANHATTAN                   PETIT LARCENY
#
#                                 PD_Desc      Law_Cat     Latitude  \
# 1139070  LEAVING SCENE-ACCIDENT-PERSONA  MISDEMEANOR  40.84812006
# 1138649                       ASSAULT 3  MISDEMEANOR    40.784781
# 1138648     INTOXICATED DRIVING,ALCOHOL  MISDEMEANOR  40.77220939
# 1138647                       ASSAULT 3  MISDEMEANOR    40.788597
# 1138646  LARCENY,PETIT FROM BUILDING,UN  MISDEMEANOR    40.788597
# 1139066                       ASSAULT 3  MISDEMEANOR  40.86510713
# 1139069                       ASSAULT 3  MISDEMEANOR    40.850452
# 1139073  LEAVING SCENE-ACCIDENT-PERSONA  MISDEMEANOR  40.86446248
# 1139082                RESISTING ARREST  MISDEMEANOR  40.79993102
# 1138650         LARCENY,PETIT FROM AUTO  MISDEMEANOR    40.785443
#
#             Longitude
# 1139070  -73.93088385
# 1138649    -73.977134
# 1138648  -73.98217925
# 1138647    -73.977179
# 1138646    -73.977179
# 1139066  -73.91844727
# 1139069    -73.938469
# 1139073  -73.91894337
# 1139082  -73.94066426
# 1138650    -73.977717

# %%
# Save cleaned_crime_df to CSV file
cleaned_crime_df.to_csv('Output/NPYD_Complaints_01-01-13_12-31-23.csv', index=False)

# %% [markdown]
# ## Drop `PD_CD` Field
# Per NYC Open Data Data Dictionary:
#  - **PD_CD**: Three digit internal classification code (more granular than Key Code)
#  - **OFNS_DESC**: Description of offense corresponding with key code
#
# There are 392 unique strings in `PD_Desc` whereas `Ofns_Desc` has 67.\
# `Ofns_Desc` will be sufficient for this project. `PD_CD` will be omitted. The resulting .csv file is ~40 MiB smaller.

# %%
# Read original CSV file
crime_df = pd.read_csv('Output/NPYD_Complaints_01-01-13_12-31-23.csv')

# %%
# Check unique values in `PD_CD` and `OFNS_DESC`
print(len(crime_df['PD_Desc'].unique().tolist()))
print(len(crime_df['Ofns_Desc'].unique().tolist()))
# Out:
# 392
# 67

# %%
# Drop `PD_CD` from DataFrame. Preview.
crime_df_update = crime_df[['Complaint_No', 'Reported_Dt', 'Borough_Name','Ofns_Desc','Law_Cat','Latitude','Longitude']]
crime_df_update.head()
# Out:
#   Complaint_No Reported_Dt Borough_Name      Ofns_Desc      Law_Cat  \
# 0    109140080  2014-03-21    MANHATTAN  GRAND LARCENY       FELONY
# 1    109140082  2014-03-21    MANHATTAN  GRAND LARCENY       FELONY
# 2    109140084  2014-03-23    MANHATTAN  HARRASSMENT 2    VIOLATION
# 3    109140085  2014-03-23    MANHATTAN  PETIT LARCENY  MISDEMEANOR
# 4    109140087  2014-03-23    MANHATTAN        FORGERY       FELONY
#
#     Latitude  Longitude
# 0  40.721109 -74.009995
# 1  40.724833 -73.997278
# 2  40.719914 -73.997070
# 3  40.724833 -73.997278
# 4  40.720656 -73.988061

# %%
# Export to CSV
crime_df_update.to_csv('Output/NPYD_Complaints_01-01-13_12-31-23_v2.csv', index=False)
